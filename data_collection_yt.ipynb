# %% [markdown]
# # **Data Collection YouTube**

# %%
import pandas as pd
from googleapiclient.discovery import build
from datetime import datetime, timedelta
import config

# %%
# API setup
api_key = config.key6
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def fetch_videos(query, max_results, days_back):
    all_videos = []
    end_date = datetime.utcnow()
    start_date = end_date - timedelta(days=days_back)

    while max_results > 0:
        published_before = end_date.isoformat("T") + "Z"
        published_after = start_date.isoformat("T") + "Z"

        search_response = youtube.search().list(
            q=query,
            part='snippet',
            maxResults=50,  # Max results per page allowed by API
            type='video',
            publishedBefore=published_before,
            publishedAfter=published_after
        ).execute()

        video_ids = [item['id']['videoId'] for item in search_response.get('items', [])]
        if video_ids:
            video_response = youtube.videos().list(
                part='snippet,statistics',
                id=','.join(video_ids)
            ).execute()

            for video in video_response.get('items', []):
                all_videos.append({
                    'Title': video['snippet']['title'],
                    'Channel': video['snippet']['channelTitle'],
                    'Published At': video['snippet']['publishedAt'],
                    'Video ID': video['id'],
                    'Likes': video['statistics'].get('likeCount', 'Not available'),
                    'Dislikes': video['statistics'].get('dislikeCount', 'Not available'),
                    'Comments': video['statistics'].get('commentCount', 'Not available')
                })

        max_results -= len(video_ids)
        end_date = start_date
        start_date -= timedelta(days=days_back)

        if not video_ids:
            break 

    return pd.DataFrame(all_videos)

# %% [markdown]
# ## **Collect data  - Tea**

# %%
search_queries_tea1 = [
    "history of tea",
    "origin of tea drinking",
    "first tea plantation",
    "tea trade history",
    "ancient tea culture",
]

# %%
search_queries_tea2 = [
    "tea in ancient China",
    "introduction of tea to Europe",
    "British tea culture history",
    "tea and the silk road",
    "oldest tea varieties",
]

# %%
# Collect data for each query
final_data_tea1 = pd.DataFrame()
for query in search_queries_tea1:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_tea1 = pd.concat([final_data_tea1, data_df], ignore_index=True)
# Out:
# Fetching data for query: history of tea
# Fetching data for query: origin of tea drinking
# Fetching data for query: first tea plantation
# Fetching data for query: tea trade history
# Fetching data for query: ancient tea culture

# %%
final_data_tea1.head(10)
# Out:
#                                                Title  \
# 0   The History Of Tea - Historia [Animated History]
# 1           Tea: How Britain Screwed India and China
# 2  The History of Tea | The Origin Of Tea | Tea's...
# 3  Robert Fortune on How Tea Was Stolen From the ...
# 4  How did tea become so popular in Great Britain...
# 5                             A brief history of tea
# 6                         Commoner Queens of England
# 7             Anne, Queen of Great Britain & Ireland
# 8         The History Of Afternoon Tea | Documentary
# 9  An Introduction to Tea in East Asia - ASMR His...
#
#                                  Channel          Published At     Video ID  \
# 0                   Mechanix Illustrated  2023-02-19T21:28:20Z  TX78tKMdJsA
# 1                            Elliot Sang  2023-09-08T17:00:11Z  2-1obrIBYN0
# 2                             KidsMathTV  2023-01-09T11:03:57Z  N6uzMv9XpKY
# 3                         SLICE Full Doc  2024-07-03T12:30:21Z  YbqtP-lH734
# 4                       Absolute History  2023-04-05T21:00:24Z  uhLl7YxQnjA
# 5                                   Neom  2022-10-25T19:00:04Z  9wfj-E5s-ws
# 6  History Tea Time with Lindsay Holiday  2024-04-16T16:00:05Z  8LEoH6SSCwM
# 7  History Tea Time with Lindsay Holiday  2024-09-03T16:00:41Z  jcNBX4UvHmk
# 8                    HistoricHospitality  2024-02-23T17:00:11Z  caFzG39lBmE
# 9                         ASMR Historian  2024-02-28T07:00:10Z  TUvEMzi7r10
#
#   Likes       Dislikes Comments
# 0   287  Not available       27
# 1  5730  Not available      357
# 2   108  Not available        0
# 3  1552  Not available      192
# 4  7291  Not available       85
# 5    94  Not available       65
# 6  6196  Not available      556
# 7  3777  Not available      222
# 8   192  Not available       35
# 9    67  Not available       13

# %%
# Collect data for each query
final_data_tea2 = pd.DataFrame()
for query in search_queries_tea2:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_tea2 = pd.concat([final_data_tea2, data_df], ignore_index=True)
# Out:
# Fetching data for query: tea in ancient China
# Fetching data for query: introduction of tea to Europe
# Fetching data for query: British tea culture history
# Fetching data for query: tea and the silk road
# Fetching data for query: oldest tea varieties

# %%
final_data_tea2.head(10)
# Out:
#                                                Title               Channel  \
# 0  Traditional tea processing techniques and asso...                UNESCO
# 1  Uncut Chinese Tea Ceremony - Wang Fu Teahouse,...      Jesse's Teahouse
# 2  The ancient ritual of the Chinese tea ceremony...  ABC News (Australia)
# 3  The History of Tea | The Origin Of Tea | Tea's...            KidsMathTV
# 4            [ASMR] Traditional Chinese Tea Ceremony              PaprTape
# 5  Ancient Chinese Tea Art: Exploring the Mysteri...         tenmoku glaze
# 6              Unveiling Ancient Chinese Tea Culture        Rewind History
# 7     What Did People Actually Eat In Ancient China?      Pages In History
# 8  The Fascinating History of Tea: From Ancient C...            Easy2learn
# 9  Exploring the Elegance of Ancient Chinese Tea ...   TheOneTimeTraveller
#
#            Published At     Video ID          Likes       Dislikes  \
# 0  2022-11-29T15:36:01Z  Oe6kGFmFLnc  Not available  Not available
# 1  2023-05-16T12:49:41Z  w8PXCOBg4EY           2613  Not available
# 2  2023-03-30T05:00:16Z  PWWOeA1UVfA             51  Not available
# 3  2023-01-09T11:03:57Z  N6uzMv9XpKY            108  Not available
# 4  2023-02-02T23:54:55Z  PIkvN5B1y98           1481  Not available
# 5  2023-02-17T09:57:21Z  24v3yigcy24             19  Not available
# 6  2024-08-21T12:00:18Z  mrINYr3cGrk              0  Not available
# 7  2023-03-10T22:00:52Z  j4tcDm6m4xk            250  Not available
# 8  2024-09-29T21:19:46Z  SgtMFk-7wt0              1  Not available
# 9  2023-12-28T13:15:02Z  ZrISiu4WqXM             64  Not available
#
#         Comments
# 0  Not available
# 1             82
# 2  Not available
# 3              0
# 4             85
# 5              2
# 6              0
# 7             21
# 8              0
# 9              0

# %% [markdown]
# Combine data frames

# %%
df_tea = pd.concat([final_data_tea1, final_data_tea2], ignore_index=True)
df_tea.head(10)
# Out:
#                                                Title  \
# 0   The History Of Tea - Historia [Animated History]
# 1           Tea: How Britain Screwed India and China
# 2  The History of Tea | The Origin Of Tea | Tea's...
# 3  Robert Fortune on How Tea Was Stolen From the ...
# 4  How did tea become so popular in Great Britain...
# 5                             A brief history of tea
# 6                         Commoner Queens of England
# 7             Anne, Queen of Great Britain & Ireland
# 8         The History Of Afternoon Tea | Documentary
# 9  An Introduction to Tea in East Asia - ASMR His...
#
#                                  Channel          Published At     Video ID  \
# 0                   Mechanix Illustrated  2023-02-19T21:28:20Z  TX78tKMdJsA
# 1                            Elliot Sang  2023-09-08T17:00:11Z  2-1obrIBYN0
# 2                             KidsMathTV  2023-01-09T11:03:57Z  N6uzMv9XpKY
# 3                         SLICE Full Doc  2024-07-03T12:30:21Z  YbqtP-lH734
# 4                       Absolute History  2023-04-05T21:00:24Z  uhLl7YxQnjA
# 5                                   Neom  2022-10-25T19:00:04Z  9wfj-E5s-ws
# 6  History Tea Time with Lindsay Holiday  2024-04-16T16:00:05Z  8LEoH6SSCwM
# 7  History Tea Time with Lindsay Holiday  2024-09-03T16:00:41Z  jcNBX4UvHmk
# 8                    HistoricHospitality  2024-02-23T17:00:11Z  caFzG39lBmE
# 9                         ASMR Historian  2024-02-28T07:00:10Z  TUvEMzi7r10
#
#   Likes       Dislikes Comments
# 0   287  Not available       27
# 1  5730  Not available      357
# 2   108  Not available        0
# 3  1552  Not available      192
# 4  7291  Not available       85
# 5    94  Not available       65
# 6  6196  Not available      556
# 7  3777  Not available      222
# 8   192  Not available       35
# 9    67  Not available       13

# %%
df_tea.shape
# Out:
# (4896, 7)

# %%
# Save the DataFrame to a CSV file
df_tea.to_csv('data_tea.csv', index=False)

# %% [markdown]
# ## **Collect data  - Coffee**

# %%
search_queries_coffee1 = [
    "history of coffee",
    "origin of coffee drinking",
    "first coffee house",
    "coffee trade history",
    "coffee in Ethiopia history"
]

# %%
search_queries_coffee2 = [
    "introduction of coffee to Europe",
    "coffee in the Ottoman Empire",
    "spread of coffee culture",
    "first coffee plantation",
    "historical impact of coffee",
]

# %%
# Collect data for each query
final_data_coffee1 = pd.DataFrame()
for query in search_queries_coffee1:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_coffee1 = pd.concat([final_data_coffee1, data_df], ignore_index=True)
# Out:
# Fetching data for query: history of coffee
# Fetching data for query: origin of coffee drinking
# Fetching data for query: first coffee house
# Fetching data for query: coffee trade history
# Fetching data for query: coffee in Ethiopia history

# %%
final_data_coffee1.head(10)
# Out:
#                                                Title  \
# 0  How humanity got hooked on coffee - Jonathan M...
# 1  Caffeine Chronicles: The Transformative Journe...
# 2                            When Coffee was Illegal
# 3  Coffee and what it does to your body - BBC Wor...
# 4         The History of Coffee || Dr Roy Casagranda
# 5  Story of the Origin of Coffee: The Legend of K...
# 6            The History of: Coffee | The History Of
# 7  Why Single-Origin Coffee Is So Expensive | So ...
# 8   How to Brew Civil War Coffee with Sweet Potatoes
# 9       Chocolate Instead of Coffee in Early America
#
#                            Channel          Published At     Video ID  Likes  \
# 0                           TED-Ed  2024-03-05T16:01:19Z  xQ156y4TtJs  33183
# 1                      Get.factual  2023-12-14T16:00:30Z  YaTjjYBxAw8   1693
# 2  Tasting History with Max Miller  2022-12-02T16:00:21Z  qvOTev_r4-8  30140
# 3                BBC World Service  2024-05-16T12:00:06Z  62wEk02YKs0  30887
# 4                   Age of Empires  2024-10-06T17:47:01Z  3k2g-W2UDEg  10990
# 5               Secrets of History  2023-03-04T02:45:45Z  Q5GtZRjhSxs     21
# 6                   The History Of  2024-08-24T20:50:14Z  08Unj_j6x_g      4
# 7                 Business Insider  2023-02-28T16:00:08Z  Dmpnrtey3YU  25607
# 8  Tasting History with Max Miller  2023-06-27T15:00:21Z  ZfOanv9oUv4  42346
# 9                        Townsends  2023-04-10T18:50:03Z  LRPHNOqABlA  26247
#
#         Dislikes Comments
# 0  Not available      560
# 1  Not available      107
# 2  Not available     1655
# 3  Not available     1892
# 4  Not available      433
# 5  Not available        1
# 6  Not available        3
# 7  Not available     1018
# 8  Not available     3244
# 9  Not available     1005

# %%
# Collect data for each query
final_data_coffee2 = pd.DataFrame()
for query in search_queries_coffee2:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_coffee2 = pd.concat([final_data_coffee2, data_df], ignore_index=True)
# Out:
# Fetching data for query: introduction of coffee to Europe
# Fetching data for query: coffee in the Ottoman Empire
# Fetching data for query: spread of coffee culture
# Fetching data for query: first coffee plantation
# Fetching data for query: historical impact of coffee

# %%
final_data_coffee2.head(10)
# Out:
#                                                Title  \
# 0  The Origin of Coffee | HOW did COFFEE come to ...
# 1  How humanity got hooked on coffee - Jonathan M...
# 2                How Turkey Brought Coffee to Europe
# 3                    Turk introduce coffee to Europe
# 4                     The medieval history of coffee
# 5                        How Coffee Spread to Europe
# 6  The Shocking Story of Coffee’s Arrival in Europe!
# 7                          How Coffee Came to Europe
# 8  Coffee's European Journey: From Controversy to...
# 9  The History of Coffee: From Goatherd's Discove...
#
#                                Channel          Published At     Video ID  \
# 0  8Grams - Italian Coffee Specialists  2023-09-03T15:55:52Z  n7t9axFrm8I
# 1                               TED-Ed  2024-03-05T16:01:19Z  xQ156y4TtJs
# 2                      Sketchy History  2023-01-18T01:51:20Z  sf2Z14f1uiQ
# 3                      Property Turkey  2023-01-13T15:27:11Z  yN5Me6dVPfc
# 4                Xeritern Perspectives  2023-12-28T06:30:07Z  D9tHLE8jAsE
# 5                            Lizpresso  2023-10-04T09:06:32Z  Ume_eeu73iY
# 6                         Morning Roar  2024-08-28T13:17:31Z  TD6MEZn5QXc
# 7                    Interesting World  2024-08-08T11:00:21Z  The-I3QbSCk
# 8                      Canned History   2024-05-04T20:00:16Z  yrORfXb4k2c
# 9                           Time Tales  2024-03-19T04:18:27Z  cQ79xb7dMXQ
#
#    Likes       Dislikes Comments
# 0     13  Not available        1
# 1  33183  Not available      560
# 2     24  Not available        1
# 3     18  Not available        0
# 4     57  Not available        0
# 5      1  Not available        0
# 6      9  Not available        0
# 7      1  Not available        0
# 8     80  Not available        1
# 9      5  Not available        1

# %% [markdown]
# Combine data frames

# %%
df_coffee = pd.concat([final_data_coffee1, final_data_coffee2], ignore_index=True)
df_coffee.head(10)
# Out:
#                                                Title  \
# 0  How humanity got hooked on coffee - Jonathan M...
# 1  Caffeine Chronicles: The Transformative Journe...
# 2                            When Coffee was Illegal
# 3  Coffee and what it does to your body - BBC Wor...
# 4         The History of Coffee || Dr Roy Casagranda
# 5  Story of the Origin of Coffee: The Legend of K...
# 6            The History of: Coffee | The History Of
# 7  Why Single-Origin Coffee Is So Expensive | So ...
# 8   How to Brew Civil War Coffee with Sweet Potatoes
# 9       Chocolate Instead of Coffee in Early America
#
#                            Channel          Published At     Video ID  Likes  \
# 0                           TED-Ed  2024-03-05T16:01:19Z  xQ156y4TtJs  33183
# 1                      Get.factual  2023-12-14T16:00:30Z  YaTjjYBxAw8   1693
# 2  Tasting History with Max Miller  2022-12-02T16:00:21Z  qvOTev_r4-8  30140
# 3                BBC World Service  2024-05-16T12:00:06Z  62wEk02YKs0  30887
# 4                   Age of Empires  2024-10-06T17:47:01Z  3k2g-W2UDEg  10990
# 5               Secrets of History  2023-03-04T02:45:45Z  Q5GtZRjhSxs     21
# 6                   The History Of  2024-08-24T20:50:14Z  08Unj_j6x_g      4
# 7                 Business Insider  2023-02-28T16:00:08Z  Dmpnrtey3YU  25607
# 8  Tasting History with Max Miller  2023-06-27T15:00:21Z  ZfOanv9oUv4  42346
# 9                        Townsends  2023-04-10T18:50:03Z  LRPHNOqABlA  26247
#
#         Dislikes Comments
# 0  Not available      560
# 1  Not available      107
# 2  Not available     1655
# 3  Not available     1892
# 4  Not available      433
# 5  Not available        1
# 6  Not available        3
# 7  Not available     1018
# 8  Not available     3244
# 9  Not available     1005

# %%
df_coffee.shape
# Out:
# (4783, 7)

# %%
# Save the DataFrame to a CSV file
df_coffee.to_csv('data_coffee.csv', index=False)

# %% [markdown]
# ## **Collect data  - Tea vs. Coffee**

# %%
search_queries_general1 = [
    
    "tea vs coffee history",
    "cultural impact of tea and coffee",
    "economic history of tea and coffee",
    "tea and coffee in colonial times",
    "how tea and coffee changed the world",
]

# %%
search_queries_general2 = [
    "tea and coffee rituals around the world",
    "historical tea and coffee ceremonies",
    "evolution of tea and coffee consumption",
    "tea and coffee in literature",
    "famous historical figures and their tea/coffee habits"
]

# %%
# Collect data for each query
final_data_general1 = pd.DataFrame()
for query in search_queries_general1:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_general1 = pd.concat([final_data_general1, data_df], ignore_index=True)
# Out:
# Fetching data for query: tea vs coffee history
# Fetching data for query: cultural impact of tea and coffee
# Fetching data for query: economic history of tea and coffee
# Fetching data for query: tea and coffee in colonial times
# Fetching data for query: how tea and coffee changed the world

# %%
final_data_general1.head(10)
# Out:
#                                                Title             Channel  \
# 0                   The Epic Battle: Tea vs. Coffee!             Shrubby
# 1  Coffee vs Tea: Which is Healthier? The Answer ...            CBN News
# 2         WHAT DO EUROPEANS LIKE MORE TEA OR COFFEE?        Macko's Maps
# 3                Tea or coffee - what do you prefer?         CGTN Europe
# 4                 🍵☕TEA or COFFEE of #countryballs ?             Rukavov
# 5                                Tea or coffee? #map           World Map
# 6                                    COFFEE VS. TEA!           Lizpresso
# 7             Does Your Country Prefer Tea or Coffee  Xenelock Geography
# 8  Experience the REAL Beauty of Shalimar Gardens...   Celtic Mick Walks
# 9                        Coffee or Tea? #shorts #fyp       Venus Mapping
#
#            Published At     Video ID          Likes       Dislikes Comments
# 0  2024-08-08T15:51:42Z  xEFMH2iFCdY             14  Not available        5
# 1  2022-11-02T20:00:00Z  25hV1udOhKo            866  Not available       78
# 2  2023-10-06T14:00:39Z  pj0VHEWSOOQ             23  Not available        0
# 3  2023-05-25T17:15:38Z  Av7alcwXEHs             11  Not available        0
# 4  2024-02-10T17:46:03Z  sLFA0RUYfxk           5378  Not available      399
# 5  2024-01-20T10:39:14Z  XFxTJTW28PY            206  Not available       30
# 6  2023-10-04T09:14:40Z  EB0HyWlXzIc             31  Not available        1
# 7  2023-10-19T11:00:14Z  DkvYsOaTvAU  Not available  Not available       29
# 8  2024-10-12T10:45:02Z  eHfXDJR4adA             56  Not available       18
# 9  2023-09-07T10:49:00Z  nUurJ7Ih6WU            873  Not available      250

# %%
# Collect data for each query
final_data_general2 = pd.DataFrame()
for query in search_queries_general2:
    print(f"Fetching data for query: {query}")
    data_df = fetch_videos(query, max_results=1000, days_back=730)
    final_data_general2 = pd.concat([final_data_general2, data_df], ignore_index=True)
# Out:
# Fetching data for query: tea and coffee rituals around the world
# Fetching data for query: historical tea and coffee ceremonies
# Fetching data for query: evolution of tea and coffee consumption
# Fetching data for query: tea and coffee in literature
# Fetching data for query: famous historical figures and their tea/coffee habits

# %%
final_data_general2.head(10)
# Out:
#                                                Title  \
# 0  Global Sips: tea, coffee or hot chocolate Disc...
# 1         How Tea and Coffee Shaped the Modern World
# 2  Discover Kyoto's Art of Traditional Matcha Tea...
# 3  International Coffee Rituals #coffee #rituals ...
# 4                                     Coffee Rituals
# 5  The Enigmatic Traditions of the Japanese Tea C...
# 6  Coffees Mesmerizing Journey From Mystical Ritu...
# 7  Uncovering the Mind Blowing Secrets of the Jap...
# 8  Life in AZERBAIJAN: The PARADISE and CHEAP Cou...
# 9  Experience tea ceremony at a traditional Korea...
#
#                           Channel          Published At     Video ID Likes  \
# 0                       Travelacy  2024-03-27T20:29:49Z  CDTBXRjAOoc    18
# 1          Tea & Coffee Explorers  2024-08-21T19:10:47Z  DozQxnEf-ok     8
# 2                   SocialTravels  2024-10-02T18:33:27Z  U17xSsAuGrE     0
# 3                   Brewhilda.com  2023-12-11T05:44:52Z  BrSLxIOM6dw     3
# 4              Phinix Coffee Cafe  2024-06-15T11:31:36Z  f1Mh8RypZCQ   365
# 5                   Coffee Minute  2023-06-05T16:23:00Z  -k6ZJ1iV1rQ     4
# 6             Let's Talk Religion  2023-11-13T13:00:56Z  vlyGWgpg6uk   513
# 7                   Coffee Minute  2023-06-05T16:20:00Z  a_ZZQrBIXh0     0
# 8         Global Life Discoveries  2024-10-11T11:30:34Z  nt7KIZkyud8    98
# 9  아니리아띠 Aniriatti & Loving Gugak  2023-07-26T15:57:18Z  BnGdzescbVU    29
#
#         Dislikes Comments
# 0  Not available        2
# 1  Not available        0
# 2  Not available        0
# 3  Not available        0
# 4  Not available        0
# 5  Not available        0
# 6  Not available       22
# 7  Not available        0
# 8  Not available       17
# 9  Not available        1

# %% [markdown]
# Combine data frames

# %%
df_general = pd.concat([final_data_general1, final_data_general2], ignore_index=True)
df_general.head(10)
# Out:
#                                                Title             Channel  \
# 0                   The Epic Battle: Tea vs. Coffee!             Shrubby
# 1  Coffee vs Tea: Which is Healthier? The Answer ...            CBN News
# 2         WHAT DO EUROPEANS LIKE MORE TEA OR COFFEE?        Macko's Maps
# 3                Tea or coffee - what do you prefer?         CGTN Europe
# 4                 🍵☕TEA or COFFEE of #countryballs ?             Rukavov
# 5                                Tea or coffee? #map           World Map
# 6                                    COFFEE VS. TEA!           Lizpresso
# 7             Does Your Country Prefer Tea or Coffee  Xenelock Geography
# 8  Experience the REAL Beauty of Shalimar Gardens...   Celtic Mick Walks
# 9                        Coffee or Tea? #shorts #fyp       Venus Mapping
#
#            Published At     Video ID          Likes       Dislikes Comments
# 0  2024-08-08T15:51:42Z  xEFMH2iFCdY             14  Not available        5
# 1  2022-11-02T20:00:00Z  25hV1udOhKo            866  Not available       78
# 2  2023-10-06T14:00:39Z  pj0VHEWSOOQ             23  Not available        0
# 3  2023-05-25T17:15:38Z  Av7alcwXEHs             11  Not available        0
# 4  2024-02-10T17:46:03Z  sLFA0RUYfxk           5378  Not available      399
# 5  2024-01-20T10:39:14Z  XFxTJTW28PY            206  Not available       30
# 6  2023-10-04T09:14:40Z  EB0HyWlXzIc             31  Not available        1
# 7  2023-10-19T11:00:14Z  DkvYsOaTvAU  Not available  Not available       29
# 8  2024-10-12T10:45:02Z  eHfXDJR4adA             56  Not available       18
# 9  2023-09-07T10:49:00Z  nUurJ7Ih6WU            873  Not available      250

# %%
df_general.shape
# Out:
# (4629, 7)

# %%
# Save the DataFrame to a CSV file
df_general.to_csv('data_tea_vs_coffee.csv', index=False)

# %% [markdown]
# ### **Combine all data frames**

# %%
df_final = pd.concat([df_tea, df_coffee, df_general], ignore_index=True)
df_final.head(10)
# Out:
#                                                Title  \
# 0   The History Of Tea - Historia [Animated History]
# 1           Tea: How Britain Screwed India and China
# 2  The History of Tea | The Origin Of Tea | Tea's...
# 3  Robert Fortune on How Tea Was Stolen From the ...
# 4  How did tea become so popular in Great Britain...
# 5                             A brief history of tea
# 6                         Commoner Queens of England
# 7             Anne, Queen of Great Britain & Ireland
# 8         The History Of Afternoon Tea | Documentary
# 9  An Introduction to Tea in East Asia - ASMR His...
#
#                                  Channel          Published At     Video ID  \
# 0                   Mechanix Illustrated  2023-02-19T21:28:20Z  TX78tKMdJsA
# 1                            Elliot Sang  2023-09-08T17:00:11Z  2-1obrIBYN0
# 2                             KidsMathTV  2023-01-09T11:03:57Z  N6uzMv9XpKY
# 3                         SLICE Full Doc  2024-07-03T12:30:21Z  YbqtP-lH734
# 4                       Absolute History  2023-04-05T21:00:24Z  uhLl7YxQnjA
# 5                                   Neom  2022-10-25T19:00:04Z  9wfj-E5s-ws
# 6  History Tea Time with Lindsay Holiday  2024-04-16T16:00:05Z  8LEoH6SSCwM
# 7  History Tea Time with Lindsay Holiday  2024-09-03T16:00:41Z  jcNBX4UvHmk
# 8                    HistoricHospitality  2024-02-23T17:00:11Z  caFzG39lBmE
# 9                         ASMR Historian  2024-02-28T07:00:10Z  TUvEMzi7r10
#
#   Likes       Dislikes Comments
# 0   287  Not available       27
# 1  5730  Not available      357
# 2   108  Not available        0
# 3  1552  Not available      192
# 4  7291  Not available       85
# 5    94  Not available       65
# 6  6196  Not available      556
# 7  3777  Not available      222
# 8   192  Not available       35
# 9    67  Not available       13

# %%
df_final.shape
# Out:
# (14308, 7)

# %%
# Save the DataFrame to a CSV file
df_final.to_csv('data_combined.csv', index=False)

# %% [markdown]
# #### **Get comments**

# %%
def initialize_youtube_client(api_key):
    return build('youtube', 'v3', developerKey=api_key)

# %%
def get_comments(youtube, video_id):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100 
    )
    response = request.execute()

    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            text = comment['textOriginal']
            author = comment['authorDisplayName']
            comments.append({'video_id': video_id, 'author': author, 'comment': text})

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=response['nextPageToken']
            ).execute()
        else:
            break

    return comments

# %%
def fetch_comments_batch(api_key, df, batch_size=10):
    youtube = initialize_youtube_client(api_key)
    all_comments = pd.DataFrame(columns=['video_id', 'author', 'comment'])

    for i in range(0, len(df), batch_size):
        batch_video_ids = df['Video ID'][i:i + batch_size]
        for video_id in batch_video_ids:
            print(f"Fetching comments for video ID: {video_id}")
            video_comments = get_comments(youtube, video_id)
            video_comments_df = pd.DataFrame(video_comments)
            all_comments = pd.concat([all_comments, video_comments_df], ignore_index=True)

    return all_comments
